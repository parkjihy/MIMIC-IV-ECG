# %% [markdown]
# # Download dataset

# %%
# Google Drive 연결
from google.colab import drive
drive.mount('/content/drive')

# 저장 경로 지정 (Google Drive 내 폴더)
save_path = '/content/drive/MyDrive/mimic_ecg/p1020'

# 폴더 생성
# !mkdir -p "{save_path}"

# PhysioNet에서 p1020 폴더 내 모든 파일 다운로드
# !wget -r -N -c -np -nH --cut-dirs=5 -P "{save_path}" https://physionet.org/files/mimic-iv-ecg/1.0/files/p1020/
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-ca2f0fba995b> in <cell line: 0>()
#       1 # Google Drive 연결
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#       4
#       5 # 저장 경로 지정 (Google Drive 내 폴더)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# 저장 경로 지정 (Google Drive 내 폴더)
save_path = '/content/drive/MyDrive/mimic_ecg/p1015'

# 폴더 생성
# !mkdir -p "{save_path}"

# PhysioNet에서 p1020 폴더 내 모든 파일 다운로드
# !wget -r -N -c -np -nH --cut-dirs=5 -P "{save_path}" https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48178561/48178561.dat’
#
# p10156269/s48178561 100%[===================>] 117.19K   426KB/s    in 0.3s
#
# 2025-05-07 13:00:06 (426 KB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48178561/48178561.dat’ saved [120000/120000]
#
# --2025-05-07 13:00:06--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156269/s48178561/48178561.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 629 [text/plain]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48178561/48178561.hea’
#
# p10156269/s48178561 100%[===================>]     629  --.-KB/s    in 0s
#
# 2025-05-07 13:00:06 (106 MB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48178561/48178561.hea’ saved [629/629]
#
# --2025-05-07 13:00:06--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156269/s48317009/48317009.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48317009/48317009.dat’
#
# p10156269/s48317009 100%[===================>] 117.19K   255KB/s    in 0.5s
#
# 2025-05-07 13:00:07 (255 KB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48317009/48317009.dat’ saved [120000/120000]
#
# --2025-05-07 13:00:07--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156269/s48317009/48317009.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 627 [text/plain]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48317009/48317009.hea’
#
# p10156269/s48317009 100%[===================>]     627  --.-KB/s    in 0s
#
# 2025-05-07 13:00:07 (49.3 MB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48317009/48317009.hea’ saved [627/627]
#
# --2025-05-07 13:00:07--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156269/s48803588/48803588.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48803588/48803588.dat’
#
# p10156269/s48803588 100%[===================>] 117.19K   425KB/s    in 0.3s
#
# 2025-05-07 13:00:07 (425 KB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48803588/48803588.dat’ saved [120000/120000]
#
# --2025-05-07 13:00:07--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156269/s48803588/48803588.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 622 [text/plain]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48803588/48803588.hea’
#
# p10156269/s48803588 100%[===================>]     622  --.-KB/s    in 0s
#
# 2025-05-07 13:00:07 (87.9 MB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s48803588/48803588.hea’ saved [622/622]
#
# --2025-05-07 13:00:07--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156269/s49953252/49953252.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s49953252/49953252.dat’
#
# p10156269/s49953252 100%[===================>] 117.19K   479KB/s    in 0.2s
#
# 2025-05-07 13:00:08 (479 KB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s49953252/49953252.dat’ saved [120000/120000]
#
# --2025-05-07 13:00:08--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156269/s49953252/49953252.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 626 [text/plain]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s49953252/49953252.hea’
#
# p10156269/s49953252 100%[===================>]     626  --.-KB/s    in 0s
#
# 2025-05-07 13:00:08 (93.6 MB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156269/s49953252/49953252.hea’ saved [626/626]
#
# --2025-05-07 13:00:08--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156272/s40505796/40505796.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156272/s40505796/40505796.dat’
#
# p10156272/s40505796 100%[===================>] 117.19K   468KB/s    in 0.3s
#
# 2025-05-07 13:00:08 (468 KB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156272/s40505796/40505796.dat’ saved [120000/120000]
#
# --2025-05-07 13:00:08--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156272/s40505796/40505796.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 628 [text/plain]
# Saving to: ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156272/s40505796/40505796.hea’
#
# p10156272/s40505796 100%[===================>]     628  --.-KB/s    in 0s
#
# 2025-05-07 13:00:08 (97.5 MB/s) - ‘/content/drive/MyDrive/mimic_ecg/p1015/p10156272/s40505796/40505796.hea’ saved [628/628]
#
# --2025-05-07 13:00:08--  https://physionet.org/files/mimic-iv-ecg/1.0/files/p1015/p10156272/
# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/AI/machine_measurements (1).csv", low_memory=False)
print(df.columns)
# Out:
# Index(['subject_id', 'study_id', 'cart_id', 'ecg_time', 'report_0', 'report_1',
#        'report_2', 'report_3', 'report_4', 'report_5', 'report_6', 'report_7',
#        'report_8', 'report_9', 'report_10', 'report_11', 'report_12',
#        'report_13', 'report_14', 'report_15', 'report_16', 'report_17',
#        'bandwidth', 'filtering', 'rr_interval', 'p_onset', 'p_end',
#        'qrs_onset', 'qrs_end', 't_end', 'p_axis', 'qrs_axis', 't_axis'],
#       dtype='object')

# %%
#ㅣ
import os
import wfdb
import numpy as np

DATA_ROOT = "/content/drive/MyDrive/mimic_ecg"

def convert_npy_from_p1024(data_root, min_folder='p1000'):
    min_index = int(min_folder[1:])  # e.g. p1024 → 1024

    for root, _, files in os.walk(data_root):
        folder_name = os.path.basename(os.path.dirname(root))
        try:
            folder_index = int(folder_name[1:])
        except:
            continue

        if folder_index < min_index:
            continue

        for file in files:
            if file.endswith('.hea'):
                record_path = os.path.join(root, file[:-4])  # without .hea
                try:
                    record = wfdb.rdrecord(record_path)
                    np.save(record_path + ".npy", record.p_signal)
                    os.remove(record_path + ".hea")
                    os.remove(record_path + ".dat")
                    print(f"✅ 변환 완료: {record_path}.npy")
                except Exception as e:
                    print(f"❌ 변환 실패: {record_path} | 이유: {e}")

# 실행
convert_npy_from_p1024(DATA_ROOT)
# Out:
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165636/s48451858/48451858.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165636/s45785017/45785017.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165636/s44952324/44952324.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s48529327/48529327.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s48498166/48498166.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s48357716/48357716.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s47838185/47838185.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s46860253/46860253.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s46445773/46445773.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s45583401/45583401.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s44828041/44828041.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s44723961/44723961.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s43883371/43883371.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s43181784/43181784.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s42593030/42593030.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s41991986/41991986.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s41460614/41460614.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s41363442/41363442.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s45937972/45937972.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s40143556/40143556.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165555/s40069136/40069136.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s49833670/49833670.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s49464662/49464662.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s49102541/49102541.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s48570628/48570628.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s48559421/48559421.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47969195/47969195.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47801633/47801633.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47644544/47644544.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47502641/47502641.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s49939343/49939343.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47502105/47502105.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47282229/47282229.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47206371/47206371.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47197981/47197981.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47081915/47081915.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s47018249/47018249.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s46950669/46950669.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s46718065/46718065.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s46513048/46513048.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s46125699/46125699.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s46015251/46015251.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s45976769/45976769.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s45827436/45827436.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s45722602/45722602.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s45696611/45696611.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s45573475/45573475.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s45341972/45341972.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s45291655/45291655.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s45172922/45172922.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s44862522/44862522.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s44715986/44715986.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s44469392/44469392.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s44334380/44334380.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s44702127/44702127.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s44214743/44214743.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s44194995/44194995.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s44187341/44187341.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s44166784/44166784.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s43823748/43823748.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s43445739/43445739.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s43429507/43429507.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s43385576/43385576.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s43282485/43282485.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s43211719/43211719.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s43122150/43122150.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s42962585/42962585.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s42845335/42845335.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s42740120/42740120.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s42711736/42711736.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s42691206/42691206.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s42615792/42615792.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s42405380/42405380.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s42143014/42143014.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s42111304/42111304.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s41700037/41700037.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s41563292/41563292.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s41539687/41539687.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s41202503/41202503.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s41168012/41168012.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s41079829/41079829.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s41068565/41068565.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s40967168/40967168.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s40698001/40698001.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s40377641/40377641.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s40327683/40327683.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s40200201/40200201.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165522/s40112786/40112786.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/s43092773/43092773.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/s42857880/42857880.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/s42655742/42655742.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/s41809127/41809127.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/s41720877/41720877.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/s41441468/41441468.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/s40877155/40877155.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/s40718667/40718667.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/s40480397/40480397.npy
# ✅ 변환 완료: /content/drive/MyDrive/mimic_ecg/p1016/p10165494/
extract_npy_files(src_directory, dest_directory)

# %%
#라벨링
import pandas as pd

# CSV 로드
df = pd.read_csv("/content/drive/MyDrive/AI/machine_measurements (1).csv")

# 전처리
df["ecg_id"] = df["study_id"].astype(str)
df["report_0"] = df["report_0"].fillna("").str.lower()

# 전체 샘플 수
total = len(df)

# AFib 라벨링
afib_df = df.copy()
afib_df["label"] = afib_df["report_0"].apply(lambda x: 1 if "atrial fibrillation" in x else 0)
afib_df[["ecg_id", "label"]].to_csv("afib_labels.csv", index=False)
afib_pos = afib_df["label"].sum()
afib_neg = total - afib_pos

# AFL 라벨링
aflt_df = df.copy()
aflt_df["label"] = aflt_df["report_0"].apply(lambda x: 1 if "atrial flutter" in x else 0)
aflt_df[["ecg_id", "label"]].to_csv("aflt_labels.csv", index=False)
aflt_pos = aflt_df["label"].sum()
aflt_neg = total - aflt_pos

# 출력
print("AFib 양성 샘플 수:", afib_pos)
print("AFib 음성 샘플 수:", afib_neg)
print("AFL 양성 샘플 수:", aflt_pos)
print("AFL 음성 샘플 수:", aflt_neg)
# Out:
# <ipython-input-62-3c22b4d1051a>:4: DtypeWarning: Columns (16,17,18,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/AI/machine_measurements (1).csv")
# AFib 양성 샘플 수: 78413
# AFib 음성 샘플 수: 721622
# AFL 양성 샘플 수: 13126
# AFL 음성 샘플 수: 786909

# %%
afib_df[["ecg_id", "report_0", "label"]].to_csv("/content/drive/MyDrive/AI/labels/afib_labeled_full.csv", index=False)

# %%
print("0 라벨 파일 수:", sum(1 for v in label_dict.values() if v == 0))
# Out:
# 0 라벨 파일 수: 0

# %%
import os

# AF, AFL 외 ECG들도 포함된 전체 데이터 디렉토리에서 파일 가져오기
data_dir = "/content/drive/MyDrive/mimic_ecg_filtered"
all_files = [f for f in os.listdir(data_dir) if f.endswith(".npy")]

print(f"[전체 ECG 파일 수] {len(all_files)}")
# Out:
# [전체 ECG 파일 수] 9679

# %% [markdown]
# # Trainnig model

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.utils.class_weight import compute_class_weight

# ======================= ⚙️ 설정 ==========================
data_dir = "/content/drive/MyDrive/mimic_ecg_filtered"
label_path = "/content/drive/MyDrive/AI/labels/Atrial_Fibrillation.csv"  # 또는 Atrial_Flutter.csv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ Using device:", device)

# =================== 파일 및 라벨 로드 =========================
label_df = pd.read_csv(label_path)
label_df["ecg_id"] = label_df["ecg_id"].astype(str)
label_dict = dict(zip(label_df["ecg_id"], label_df["PRED"]))  # 0 or 1

all_files = [f for f in os.listdir(data_dir) if f.endswith(".npy")]
labeled_files = [f for f in all_files if f.split(".")[0] in label_dict]
labels_for_split = [label_dict[f.split(".")[0]] for f in labeled_files]

print(f"[총 ECG 파일 수] {len(all_files)}")
print(f"[라벨 포함 파일 수] {len(labeled_files)}")
print(f"양성 라벨 수: {sum(labels_for_split)}")
print(f"음성 라벨 수: {len(labels_for_split) - sum(labels_for_split)}")

# ===================== Stratified Shuffle Split =====================
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_idx, test_idx in splitter.split(labeled_files, labels_for_split):
    train_files = [labeled_files[i] for i in train_idx]
    test_files = [labeled_files[i] for i in test_idx]

# ==================== Dataset 클래스 =======================
class ECGDataset(Dataset):
    def __init__(self, file_list):
        self.file_list = file_list

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        filename = self.file_list[idx]
        filepath = os.path.join(data_dir, filename)
        signal = np.load(filepath)

        signal = np.nan_to_num(signal)
        signal = (signal - np.mean(signal)) / (np.std(signal) + 1e-7)

        signal_cnn = torch.tensor(signal.T, dtype=torch.float32)
        signal_lstm = torch.tensor(signal, dtype=torch.float32)
        label = torch.tensor(label_dict[filename.split(".")[0]], dtype=torch.float32)
        return signal_cnn, signal_lstm, label

# ==================== 모델 정의 ==========================
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv1d(12, 16, kernel_size=7, padding=3)
        self.pool1 = nn.MaxPool1d(2)
        self.conv2 = nn.Conv1d(16, 32, kernel_size=5, padding=2)
        self.pool2 = nn.MaxPool1d(2)
        self.fc1 = nn.Linear(32 * 1250, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        x = self.pool1(torch.relu(self.conv1(x)))
        x = self.pool2(torch.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        return self.fc2(x)

class LSTMModel(nn.Module):
    def __init__(self):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size=12, hidden_size=64, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(64 * 2, 1)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = lstm_out[:, -1, :]
        return self.fc(out)

# ==================== 학습 및 평가 함수 ========================
def train_eval(model, train_loader, test_loader, model_type='cnn', epochs=5):
    model = model.to(device)
    classes = np.unique(labels_for_split)
    class_weights = compute_class_weight('balanced', classes=classes, y=labels_for_split)
    pos_weight = torch.tensor([class_weights[0]], dtype=torch.float32).to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    optimizer = optim.Adam(model.parameters(), lr=1e-5)

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for x_cnn, x_lstm, labels in train_loader:
            inputs = x_cnn if model_type == 'cnn' else x_lstm
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs).squeeze()
            loss = criterion(outputs, labels)
            if torch.isnan(loss):
                print("❌ NaN loss 발생")
                return None
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"Epoch {epoch+1} | Loss: {total_loss / len(train_loader):.4f}")

    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for x_cnn, x_lstm, labels in test_loader:
            inputs = x_cnn if model_type == 'cnn' else x_lstm
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = torch.sigmoid(model(inputs).squeeze())
            all_preds.extend(outputs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    preds_bin = [1 if p > 0.5 else 0 for p in all_preds]
    acc = accuracy_score(all_labels, preds_bin)
    f1 = f1_score(all_labels, preds_bin)
    try:
        auc = roc_auc_score(all_labels, all_preds)
    except ValueError:
        auc = float('nan')
    print(f"✅ Accuracy: {acc:.4f} | F1: {f1:.4f} | AUC: {auc:.4f}")
    return {"acc": acc, "f1": f1, "auc": auc}

# =================== 학습 시작 ============================
train_dataset = ECGDataset(train_files)
test_dataset = ECGDataset(test_files)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64)

models = [CNN(), LSTMModel()]
model_names = ["CNN", "LSTM"]
results = {}

for model, name in zip(models, model_names):
    print(f"\n📌 [{name}] Training and Evaluation...")
    model_type = 'cnn' if name == "CNN" else 'lstm'
    metrics = train_eval(model, train_loader, test_loader, model_type=model_type)
    if metrics:
        results[name] = metrics

print("📊 결과:", results)

# =================== 라벨 분포 확인 ========================
train_labels = [label_dict[f.split(".")[0]] for f in train_files]
print("🔍 학습 라벨 분포:", dict(zip(*np.unique(train_labels, return_counts=True))))

test_labels = [label_dict[f.split(".")[0]] for f in test_files]
print("🔍 테스트 라벨 분포:", dict(zip(*np.unique(test_labels, return_counts=True))))
# Out:
# ✅ Using device: cuda
# [총 ECG 파일 수] 9679
# [라벨 포함 파일 수] 9679
# 양성 라벨 수: 986
# 음성 라벨 수: 8693
#
# 📌 [CNN] Training and Evaluation...
# Epoch 1 | Loss: 0.2467
# Epoch 2 | Loss: 0.2090
# Epoch 3 | Loss: 0.2036
# Epoch 4 | Loss: 0.1987
# Epoch 5 | Loss: 0.1943
# ✅ Accuracy: 0.8982 | F1: 0.0000 | AUC: 0.6563
#
# 📌 [LSTM] Training and Evaluation...
# Epoch 1 | Loss: 0.6642
# Epoch 2 | Loss: 0.6561
# Epoch 3 | Loss: 0.6477
# Epoch 4 | Loss: 0.6391
# Epoch 5 | Loss: 0.6299
# ✅ Accuracy: 0.8905 | F1: 0.0185 | AUC: 0.5136
# 📊 결과: {'CNN': {'acc': 0.8982438016528925, 'f1': 0.0, 'auc': np.float64(0.6562876733521512)}, 'LSTM': {'acc': 0.890495867768595, 'f1': 0.018518518518518517, 'auc': np.float64(0.5135777315278341)}}
# 🔍 학습 라벨 분포: {np.int64(0): np.int64(6954), np.int64(1): np.int64(789)}
# 🔍 테스트 라벨 분포: {np.int64(0): np.int64(1739), np.int64(1): np.int64(197)}

# %%
#CNN_LSTM_SE 모델 구현
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.fc1 = nn.Linear(channels, channels // reduction)
        self.fc2 = nn.Linear(channels // reduction, channels)

    def forward(self, x):
        # x: (batch, channels, seq_len)
        b, c, t = x.size()
        squeeze = x.mean(dim=2)  # (batch, channels)
        excitation = torch.relu(self.fc1(squeeze))
        excitation = torch.sigmoid(self.fc2(excitation)).unsqueeze(2)  # (batch, channels, 1)
        return x * excitation  # (batch, channels, seq_len)

class CNN_LSTM_SE(nn.Module):
    def __init__(self):
        super(CNN_LSTM_SE, self).__init__()
        self.conv1 = nn.Conv1d(12, 32, kernel_size=7, padding=3)
        self.bn1 = nn.BatchNorm1d(32)
        self.se1 = SEBlock(32)

        self.pool = nn.MaxPool1d(2)
        self.lstm = nn.LSTM(input_size=32, hidden_size=64, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(64 * 2, 1)

    def forward(self, x):  # x: (batch, 12, 5000)
        x = torch.relu(self.bn1(self.conv1(x)))  # (batch, 32, 5000)
        x = self.se1(x)  # (batch, 32, 5000)
        x = self.pool(x)  # (batch, 32, 2500)
        x = x.permute(0, 2, 1)  # (batch, 2500, 32)
        lstm_out, _ = self.lstm(x)  # (batch, 2500, 128)
        out = lstm_out[:, -1, :]  # (batch, 128)
        return self.fc(out)  # (batch, 1)

# %%
models = [CNN(), LSTMModel(), CNN_LSTM_SE()]
model_names = ["CNN", "LSTM", "CNN-LSTM-SE"]
results = {}

for model, name in zip(models, model_names):
    print(f"\n📌 [{name}] Training and Evaluation...")
    model_type = 'cnn' if "CNN" in name else 'lstm'  # CNN, CNN-LSTM-SE → cnn
    metrics = train_eval(model, train_loader, test_loader, model_type=model_type)
    if metrics:
        results[name] = metrics

print("📊 결과:", results)
# Out:
# 📌 [CNN] Training and Evaluation...
# Epoch 1 | Loss: 0.2531
# Epoch 2 | Loss: 0.2138
# Epoch 3 | Loss: 0.2089
# Epoch 4 | Loss: 0.2044
# Epoch 5 | Loss: 0.2001
# ✅ Accuracy: 0.8982 | F1: 0.0000 | AUC: 0.6406
#
# 📌 [LSTM] Training and Evaluation...
# Epoch 1 | Loss: 0.7014
# Epoch 2 | Loss: 0.6932
# Epoch 3 | Loss: 0.6850
# Epoch 4 | Loss: 0.6766
# Epoch 5 | Loss: 0.6678
# ✅ Accuracy: 0.3399 | F1: 0.1755 | AUC: 0.4950
#
# 📌 [CNN-LSTM-SE] Training and Evaluation...
# Epoch 1 | Loss: 0.6450
# Epoch 2 | Loss: 0.6330

# %%
import matplotlib.pyplot as plt

def plot_results(results_dict):
    models = list(results_dict.keys())
    accs = [results_dict[m]["acc"] for m in models]
    f1s = [results_dict[m]["f1"] for m in models]
    aucs = [results_dict[m]["auc"] for m in models]

    x = range(len(models))
    width = 0.25

    plt.figure(figsize=(10, 6))
    plt.bar([i - width for i in x], accs, width=width, label='Accuracy')
    plt.bar(x, f1s, width=width, label='F1 Score')
    plt.bar([i + width for i in x], aucs, width=width, label='AUC')

    plt.xticks(ticks=x, labels=models)
    plt.ylabel("Score")
    plt.title("✅ Model Comparison: Accuracy / F1 / AUC")
    plt.legend()
    plt.grid(axis='y')
    plt.ylim(0, 1.1)
    plt.show()



plot_results(results)

# %%
import matplotlib.pyplot as plt

def plot_results(results_dict):
    models = list(results_dict.keys())
    accs = [results_dict[m]["acc"] for m in models]
    f1s = [results_dict[m]["f1"] for m in models]
    aucs = [results_dict[m]["auc"] for m in models]

    plt.figure(figsize=(10, 6))

    # Plot lines with enhanced design
    plt.plot(models, accs, marker='o', label='Accuracy', linestyle='-', color='#1f77b4', markersize=8, linewidth=2)
    plt.plot(models, f1s, marker='s', label='F1 Score', linestyle='--', color='#ff7f0e', markersize=8, linewidth=2)
    plt.plot(models, aucs, marker='^', label='AUC', linestyle='-.', color='#2ca02c', markersize=8, linewidth=2)

    # Title and labels with professional fonts
    plt.title("✅ Model Comparison: Accuracy / F1 / AUC", fontsize=16, fontweight='bold', family='Arial')
    plt.ylabel("Score", fontsize=14, fontweight='bold', family='Arial')
    plt.xticks(fontsize=12, family='Arial', rotation=45)
    plt.yticks(fontsize=12, family='Arial')

    # Adding gridlines and customizing background
    plt.grid(True, linestyle=':', color='gray', alpha=0.7)
    plt.gca().set_facecolor('#f9f9f9')  # Light background color

    # Adjust plot limits
    plt.ylim(0, 1.1)

    # Add legend with a refined style
    plt.legend(loc='upper left', fontsize=12, frameon=False)

    # Show the plot
    plt.tight_layout()  # Adjust layout for better fitting
    plt.show()

# Example usage:
# plot_results(results)

# %%
torch.save(model.state_dict(), f"{name}_best_model.pt")
print(f"💾 모델 저장 완료: {name}_best_model.pt")

#모델 저장
for model, name in zip(models, model_names):
    model_type = 'cnn' if "CNN" in name else 'lstm'
    print(f"\n📌 [{name}] Training and Evaluation...")
    metrics = train_eval(model, train_loader, test_loader, model_type=model_type)
    if metrics:
        results[name] = metrics
        torch.save(model.state_dict(), f"{name}_best_model.pt")
        print(f"💾 저장됨: {name}_best_model.pt")
